# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
def load_data(file_path):
    data = {'time': [], 'cv_00': [], 'potential': []}
    
    with open(file_path, 'r') as file:
        for line in file:
            time_match = re.search(r'\[time \[([\d\.]+)\]\]', line)
            cv_00_match = re.search(r'\[cv_00 \[([\d\.-]+)\]\]', line)
            potential_match = re.search(r'\[potential \[([\d\.]+)\]\]', line)
            
            if time_match and cv_00_match and potential_match:
                data['time'].append(float(time_match.group(1)))
                data['cv_00'].append(float(cv_00_match.group(1)))
                data['potential'].append(float(potential_match.group(1)))
    return pd.DataFrame(data)


def plot_custom_colored_data(df):
    plt.figure(figsize=(10, 6))
    
    plt.scatter(df['time'], df['cv_00'], color='black', label='All Data Points')
    
    yellow_light_condition = (df['cv_00'] >= 2) & (df['cv_00'] < 3) & (df['potential'] <= 1)
    plt.scatter(df['time'][yellow_light_condition], df['cv_00'][yellow_light_condition], 
                color='lightyellow', label='2 <= CV < 3 and Potential <= 0.6')
    
    yellow_strong_condition = (df['cv_00'] >= 2) & (df['cv_00'] < 3) & (df['potential'] <= 1)
    plt.scatter(df['time'][yellow_strong_condition], df['cv_00'][yellow_strong_condition], 
                color='yellow', label='2 <= CV < 3 and Potential <= 0.5')
    
    blue_light_condition = (df['cv_00'] <= -2) & (df['cv_00'] > -3) & (df['potential'] <= 1)
    plt.scatter(df['time'][blue_light_condition], df['cv_00'][blue_light_condition], 
                color='lightblue', label='-3 < CV <= -2 and Potential <= 0.5')
    
    blue_strong_condition = (df['cv_00'] <= -2) & (df['cv_00'] > -3) & (df['potential'] <= 1)
    plt.scatter(df['time'][blue_strong_condition], df['cv_00'][blue_strong_condition], 
                color='blue', label='-3 < CV <= -2 and Potential <= 0.4')
    
    plt.xlabel('Time')
    plt.ylabel('cv_00')
    plt.title('Custom Colored Dot Plot of cv_00 over Time')
    plt.legend()
    plt.show()

# %%
file_path = './META_CV1_KL201_100ns_H0.001_W5_kTemp1.7/META_CV1_KL201_100ns_H0.001_W5_kTemp1.7.cvseq'
df = load_data(file_path)
plot_custom_colored_data(df)

# %%
file_path = './META_CV1_KL201_100ns_H0.003_W5_kTemp1.7/META_CV1_KL201_100ns_H0.003_W5_kTemp1.7.cvseq'
df = load_data(file_path)
plot_custom_colored_data(df)

# %%
file_path = './META_CV1_TH301_100ns_H0.001_W5_kTemp1.7/META_CV1_TH301_100ns_H0.001_W5_kTemp1.7.cvseq'
df = load_data(file_path)
plot_custom_colored_data(df)

# %%
file_path = './META_CV1_TH301_100ns_H0.003_W5_kTemp1.7/META_CV1_TH301_100ns_H0.003_W5_kTemp1.7.cvseq'
df = load_data(file_path)
plot_custom_colored_data(df)

# %%
def load_data(file_path):
    data = {'time': [], 'cv_00': [], 'potential': []}
    
    with open(file_path, 'r') as file:
        for line in file:
            time_match = re.search(r'\[time \[([\d\.]+)\]\]', line)
            cv_00_match = re.search(r'\[cv_00 \[([\d\.-]+)\]\]', line)
            potential_match = re.search(r'\[potential \[([\d\.]+)\]\]', line)
            
            if time_match and cv_00_match and potential_match:
                data['time'].append(float(time_match.group(1)))
                data['cv_00'].append(float(cv_00_match.group(1)))
                data['potential'].append(float(potential_match.group(1)))
    return pd.DataFrame(data)


def plot_custom_colored_data(df):
    plt.figure(figsize=(10, 6))
    
    plt.scatter(df['time'], df['cv_00'], color='black', label='All Data Points')

    
    yellow_strong_condition = (df['cv_00'] >= 1) & (df['cv_00'] < 2) & (df['potential'] <= 2)
    plt.scatter(df['time'][yellow_strong_condition], df['cv_00'][yellow_strong_condition], 
                color='yellow', label='2 <= CV < 3 and Potential <= 0.5')

    
    blue_strong_condition = (df['cv_00'] <= -1) & (df['cv_00'] > -2) & (df['potential'] <= 2)
    plt.scatter(df['time'][blue_strong_condition], df['cv_00'][blue_strong_condition], 
                color='blue', label='-3 < CV <= -2 and Potential <= 0.4')
    
    plt.xlabel('Time')
    plt.ylabel('cv_00')
    plt.title('Custom Colored Dot Plot of cv_00 over Time')
    plt.legend()
    plt.show()
    
file_path = './META_CV1_TH301_100ns_H0.003_W5_kTemp1.7/META_CV1_TH301_100ns_H0.003_W5_kTemp1.7.cvseq'
df = load_data(file_path)
plot_custom_colored_data(df)

# %%
def load_data(file_path):
    data = {'time': [], 'cv_00': [], 'potential': []}
    
    with open(file_path, 'r') as file:
        for line in file:
            time_match = re.search(r'\[time \[([\d\.]+)\]\]', line)
            cv_00_match = re.search(r'\[cv_00 \[([\d\.-]+)\]\]', line)
            potential_match = re.search(r'\[potential \[([\d\.]+)\]\]', line)
            
            if time_match and cv_00_match and potential_match:
                data['time'].append(float(time_match.group(1)))
                data['cv_00'].append(float(cv_00_match.group(1)))
                data['potential'].append(float(potential_match.group(1)))
    return pd.DataFrame(data)


def plot_custom_colored_data(df):
    plt.figure(figsize=(10, 6))
    
    plt.scatter(df['time'], df['cv_00'], color='black', label='All Data Points')
    

    yellow_strong_condition = (df['cv_00'] >= 1) & (df['cv_00'] < 2) & (df['potential'] <= 3)
    plt.scatter(df['time'][yellow_strong_condition], df['cv_00'][yellow_strong_condition], 
                color='yellow', label='2 <= CV < 3 and Potential <= 0.5')
    
    blue_strong_condition = (df['cv_00'] <= -1) & (df['cv_00'] > -2) & (df['potential'] <= 3)
    plt.scatter(df['time'][blue_strong_condition], df['cv_00'][blue_strong_condition], 
                color='blue', label='-3 < CV <= -2 and Potential <= 0.4')
    
    plt.xlabel('Time')
    plt.ylabel('cv_00')
    plt.title('Custom Colored Dot Plot of cv_00 over Time')
    plt.legend()
    plt.show()

def plot_potential_energy_over_time(df):
    plt.figure(figsize=(10, 6))
    plt.plot(df['time'], df['potential'], color='green', label='Potential Energy')
    
    plt.xlabel('Time')
    plt.ylabel('Potential Energy')
    plt.title('Potential Energy over Time')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    
file_path = './META_CV1_TH301_100ns_H0.001_W5_kTemp1.7/META_CV1_TH301_100ns_H0.001_W5_kTemp1.7.cvseq'
df = load_data(file_path)
plot_custom_colored_data(df)
plot_potential_energy_over_time(df)

# %%
def load_data(file_path):
    data = {'time': [], 'cv_01': [], 'potential': []}
    
    with open(file_path, 'r') as file:
        for line in file:
            time_match = re.search(r'\[time \[([\d\.]+)\]\]', line)
            cv_01_match = re.search(r'\[cv_01 \[([\d\.-]+)\]\]', line)
            potential_match = re.search(r'\[potential \[([\d\.]+)\]\]', line)
            
            if time_match and cv_01_match and potential_match:
                data['time'].append(float(time_match.group(1)))
                data['cv_01'].append(float(cv_01_match.group(1)))
                data['potential'].append(float(potential_match.group(1)))
    return pd.DataFrame(data)


def plot_custom_colored_data(df):
    plt.figure(figsize=(10, 6))
    
    plt.scatter(df['time'], df['cv_01'], color='black', label='All Data Points')
    

    yellow_strong_condition = (df['cv_01'] >= 1) & (df['cv_01'] < 2) & (df['potential'] <= 2)
    plt.scatter(df['time'][yellow_strong_condition], df['cv_01'][yellow_strong_condition], 
                color='yellow', label='2 <= CV < 3 and Potential <= 0.5')
    
    blue_strong_condition = (df['cv_01'] <= -1) & (df['cv_01'] > -2) & (df['potential'] <= 2)
    plt.scatter(df['time'][blue_strong_condition], df['cv_01'][blue_strong_condition], 
                color='blue', label='-3 < CV <= -2 and Potential <= 0.4')
    
    plt.xlabel('Time')
    plt.ylabel('cv_01')
    plt.title('Custom Colored Dot Plot of cv_01 over Time')
    plt.legend()
    plt.show()
        
def plot_potential_energy_over_time(df):
    plt.figure(figsize=(10, 6))
    plt.plot(df['time'], df['potential'], color='green', label='Potential Energy')
    
    plt.xlabel('Time')
    plt.ylabel('Potential Energy')
    plt.title('Potential Energy over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

    
file_path = './META_CV2_TH301_20ns_H0.003_W5/META_CV2_TH301_20ns_H0.003_W5.cvseq'
df = load_data(file_path)
plot_custom_colored_data(df)
plot_potential_energy_over_time(df)
